# %% [raw]
# ---
# title: "15-1. 강화학습(LunarLander)"
# author: "이상민"
# date: "06/15/2025"
# ---

# %% [markdown]
# ### 1. imports

# %%
import gymnasium as gym
#--#
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import IPython
#--#
import collections
import random
#--#
import torch
